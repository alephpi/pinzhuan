# %%
import numpy as np

# bool 数组
mask = np.array([True, False, True, True, False, False, True, False])

# ❌ 直接输入 bool 会报错
try:
    packed = np.packbits(mask)
except TypeError as e:
    print(f"错误: {e}")
    # 错误: packbits() argument 1 must be integer array, not bool

# ✅ 必须转成整数类型
# packed = np.packbits(mask.astype(np.uint8))
# print(packed)  # [0b10110010]

# %%
packed = np.packbits(mask)

# %%
bytes(packed[0])
# Out:
# b''
